# %%
import pandas as pd

# %%
df = pd.read_csv('/content/modified_ais_data.csv',nrows=1000)

# %%
df.head()
# Out:
#           BaseDateTime       MMSI         IMO       LAT        LON   SOG  \
# 0  2022-03-31T00:00:01  671226100  IMO9221322  25.77626  -80.20320   3.2
# 1  2022-03-31T00:00:06  367452810  IMO9602344  29.32824  -94.77391   2.6
# 2  2022-03-31T00:00:09  366919770  IMO9253583  48.74428 -122.49504   0.0
# 3  2022-03-31T00:00:00  311000966  IMO8916607  18.55833  -66.47910  17.5
# 4  2022-03-31T00:00:01  219028420  IMO9411305  28.66703  -93.59339   9.5
#
#      COG
# 0  143.7
# 1  319.2
# 2  210.3
# 3  274.5
# 4  129.4

# %%
import math

def lat_lon_to_cartesian(lat, lon, R=6371):
    lat_rad = math.radians(lat)
    lon_rad = math.radians(lon)
    x = R * math.cos(lat_rad) * math.cos(lon_rad)
    y = R * math.cos(lat_rad) * math.sin(lon_rad)
    z = R * math.sin(lat_rad)
    return x, y, z

def cartesian_to_lat_lon(x, y, z, R=6371):
    lon = math.degrees(math.atan2(y, x))
    lat = math.degrees(math.asin(z / R))
    return lat, lon

# %%
df[['x', 'y', 'z']] = df.apply(lambda row: pd.Series(lat_lon_to_cartesian(row['LAT'], row['LON'])), axis=1)

# %%
df.head()
# Out:
#           BaseDateTime       MMSI         IMO       LAT        LON   SOG  \
# 0  2022-03-31T00:00:01  671226100  IMO9221322  25.77626  -80.20320   3.2
# 1  2022-03-31T00:00:06  367452810  IMO9602344  29.32824  -94.77391   2.6
# 2  2022-03-31T00:00:09  366919770  IMO9253583  48.74428 -122.49504   0.0
# 3  2022-03-31T00:00:00  311000966  IMO8916607  18.55833  -66.47910  17.5
# 4  2022-03-31T00:00:01  219028420  IMO9411305  28.66703  -93.59339   9.5
#
#      COG            x            y            z
# 0  143.7   976.189651 -5653.417795  2770.480464
# 1  319.2  -462.261129 -5535.146877  3120.593645
# 2  210.3 -2256.980451 -3543.426543  4789.552023
# 3  274.5  2410.348516 -5537.896973  2027.697745
# 4  129.4  -350.359001 -5579.067584  3056.287693

# %%
import numpy as np
def haversine(lat1, lon1, lat2, lon2, R=6371):
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = np.sin(dlat / 2) ** 2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2) ** 2
    c = 2 * np.arcsin(np.sqrt(a))
    return R * c

# %%
df["BaseDateTime"] = pd.to_datetime(df["BaseDateTime"])

# %%
def calculate_distances(group):
    group = group.sort_values(by="BaseDateTime")
    group["next_lat"] = group["LAT"].shift(-1)
    group["next_long"] = group["LON"].shift(-1)
    group["distance_km"] = group.apply(
        lambda row: haversine(row["LAT"], row["LON"], row["next_lat"], row["next_long"])
        if not np.isnan(row["next_lat"])
        else 0,
        axis=1,
    )
    return group.drop(columns=["next_lat", "next_long"])

# %%
df = df.groupby("MMSI").apply(calculate_distances).reset_index(drop=True)
df.head()
# Out:
# <ipython-input-11-e18fd20cbb70>:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby("MMSI").apply(calculate_distances).reset_index(drop=True)
#          BaseDateTime       MMSI         IMO       LAT        LON   SOG  \
# 0 2022-03-31 00:00:17    1056261  IMO1056261  26.11809  -80.14815   0.1
# 1 2022-03-31 00:01:13  209136000  IMO9416707  45.64101 -122.74869   0.0
# 2 2022-03-31 00:00:01  209513000  IMO9060247  26.09387  -80.08081  28.3
# 3 2022-03-31 00:01:03  209513000  IMO9060247  26.09386  -80.08645  14.9
# 4 2022-03-31 00:00:00  209613000  IMO9266542  29.80067  -79.81317  10.6
#
#      COG            x            y            z  distance_km
# 0  220.5   978.775466 -5636.091653  2804.658708     0.000000
# 1  218.5 -2409.574733 -3746.291746  4555.094813     0.000000
# 2  272.6   985.603053 -5636.104757  2802.240317     0.563219
# 3  269.4   985.048333 -5636.202230  2802.239319     0.000000
# 4  186.0   977.761677 -5441.347041  3166.285755     0.000000

# %%
def calculate_durations(group):
    # Ensure BaseDateTime is a datetime type
    group['BaseDateTime'] = pd.to_datetime(group['BaseDateTime'])
    # Calculate the duration between consecutive points in seconds
    group['duration_seconds'] = group['BaseDateTime'].diff().dt.total_seconds()
    return group

# %%
df = df.groupby("MMSI", group_keys=False).apply(calculate_durations)
df = df.reset_index(drop=True)
df.head()
# Out:
# <ipython-input-13-1fbd24d56e1c>:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby("MMSI", group_keys=False).apply(calculate_durations)
#          BaseDateTime       MMSI         IMO       LAT        LON   SOG  \
# 0 2022-03-31 00:00:17    1056261  IMO1056261  26.11809  -80.14815   0.1
# 1 2022-03-31 00:01:13  209136000  IMO9416707  45.64101 -122.74869   0.0
# 2 2022-03-31 00:00:01  209513000  IMO9060247  26.09387  -80.08081  28.3
# 3 2022-03-31 00:01:03  209513000  IMO9060247  26.09386  -80.08645  14.9
# 4 2022-03-31 00:00:00  209613000  IMO9266542  29.80067  -79.81317  10.6
#
#      COG            x            y            z  distance_km  duration_seconds
# 0  220.5   978.775466 -5636.091653  2804.658708     0.000000               NaN
# 1  218.5 -2409.574733 -3746.291746  4555.094813     0.000000               NaN
# 2  272.6   985.603053 -5636.104757  2802.240317     0.563219               NaN
# 3  269.4   985.048333 -5636.202230  2802.239319     0.000000              62.0
# 4  186.0   977.761677 -5441.347041  3166.285755     0.000000               NaN

# %%
# Define constants
KNOTS_TO_METERS_PER_SEC = 0.514444
df['sog_mps'] = df['SOG'].apply(lambda x: x * KNOTS_TO_METERS_PER_SEC)
df['cog_radians'] = df['COG'].apply(lambda x: np.radians(x))

# %%
df = df[['x','y','z','duration_seconds','distance_km','sog_mps','cog_radians']]

# %%
df.head()
# Out:
#              x            y            z  duration_seconds  distance_km  \
# 0   978.775466 -5636.091653  2804.658708               NaN     0.000000
# 1 -2409.574733 -3746.291746  4555.094813               NaN     0.000000
# 2   985.603053 -5636.104757  2802.240317               NaN     0.563219
# 3   985.048333 -5636.202230  2802.239319              62.0     0.000000
# 4   977.761677 -5441.347041  3166.285755               NaN     0.000000
#
#      sog_mps  cog_radians
# 0   0.051444     3.848451
# 1   0.000000     3.813544
# 2  14.558765     4.757768
# 3   7.665216     4.701917
# 4   5.453106     3.246312

# %%
df.dropna(inplace=True)

# %%
df.head()
# Out:
#               x            y            z  duration_seconds  distance_km  \
# 3    985.048333 -5636.202230  2802.239319              62.0          0.0
# 8   1038.813807 -5617.560112  2820.199507              66.0          0.0
# 28   964.816679 -5298.686551  3403.335218              69.0          0.0
# 32   945.221036 -5275.068348  3445.265174              69.0          0.0
# 48  1043.049048 -5653.562549  2745.709415              61.0          0.0
#
#      sog_mps  cog_radians
# 3   7.665216     4.701917
# 8   7.459438     0.713840
# 28  5.813217     4.066617
# 32  6.173328     2.089159
# 48  6.276217     3.267256

# %% [markdown]
# # attention (en+de)

# %%
# import numpy as np
# import pandas as pd
# import tensorflow as tf
# import matplotlib.pyplot as plt
# from tensorflow.keras.models import Model
# from tensorflow.keras.layers import (
#     Input, Dense, MultiHeadAttention, LayerNormalization, Dropout, TimeDistributed, Lambda
# )
# from tensorflow.keras.optimizers import Adam
# from sklearn.preprocessing import MinMaxScaler


# # Split data to prevent leakage
# train_size = int(len(df) * 0.8)
# train_data = df.iloc[:train_size]
# test_data = df.iloc[train_size:]

# # Scale separately to avoid data leakage
# scaler = MinMaxScaler()
# scaled_train = scaler.fit_transform(train_data)
# scaled_test = scaler.transform(test_data)

# # Function to create sequences with step size = seq_length
# def create_sequences(data, seq_length):
#     X, decoder_inputs, decoder_targets = [], [], []

#     for i in range(0, len(data) - seq_length, seq_length):  # Step size = seq_length
#         X.append(data[i:i+seq_length])  # Encoder input: Full sequence

#         # Decoder input: Start token + shifted sequence
#         start_token = np.zeros((1, data.shape[1]))  # Start token (1 row of zeros)
#         decoder_in = np.vstack([start_token, data[i+1:i+seq_length]])

#         # Decoder target: Shifted sequence
#         decoder_target = data[i+1:i+seq_length+1]

#         decoder_inputs.append(decoder_in)
#         decoder_targets.append(decoder_target)

#     return np.array(X), np.array(decoder_inputs), np.array(decoder_targets)

# seq_length = 10  # Look at last 10 time steps
# X_train, decoder_inputs_train, decoder_targets_train = create_sequences(scaled_train, seq_length)
# X_test, decoder_inputs_test, decoder_targets_test = create_sequences(scaled_test, seq_length)

# # Transformer Encoder Block
# def transformer_encoder(inputs, num_heads=4, ff_dim=64, dropout_rate=0.1):
#     input_dim = tf.keras.backend.int_shape(inputs)[-1]
#     key_dim = max(1, input_dim // num_heads)

#     attention_norm = LayerNormalization(epsilon=1e-6)(inputs)
#     attention = MultiHeadAttention(num_heads=num_heads, key_dim=key_dim)(attention_norm, attention_norm)
#     attention = Dropout(dropout_rate)(attention)
#     attention = inputs + attention
#     attention = LayerNormalization(epsilon=1e-6)(attention)

#     ff_output = Dense(ff_dim, activation="relu")(attention)
#     ff_output = Dense(input_dim)(ff_output)
#     ff_output = Dropout(dropout_rate)(ff_output)

#     return LayerNormalization(epsilon=1e-6)(attention + ff_output)

# # Transformer Decoder Block with Causal Mask
# def transformer_decoder(inputs, encoder_outputs, num_heads=4, ff_dim=64, dropout_rate=0.1):
#     input_dim = tf.keras.backend.int_shape(inputs)[-1]
#     key_dim = max(1, input_dim // num_heads)

#     # Define causal mask using Lambda layer
#     def create_causal_mask(seq_len):
#         mask = tf.linalg.band_part(tf.ones((seq_len, seq_len)), -1, 0)  # Lower triangular mask
#         return 1 - mask  # Invert: 1 where to mask, 0 where allowed

#     causal_mask = Lambda(lambda x: create_causal_mask(tf.shape(x)[1]))(inputs)

#     attention_norm = LayerNormalization(epsilon=1e-6)(inputs)
#     attention1 = MultiHeadAttention(num_heads=num_heads, key_dim=key_dim)(
#         attention_norm, attention_norm, attention_mask=causal_mask
#     )
#     attention1 = Dropout(dropout_rate)(attention1)
#     attention1 = inputs + attention1
#     attention1 = LayerNormalization(epsilon=1e-6)(attention1)

#     attention2 = MultiHeadAttention(num_heads=num_heads, key_dim=key_dim)(
#         query=attention1, key=encoder_outputs, value=encoder_outputs
#     )
#     attention2 = Dropout(dropout_rate)(attention2)
#     attention2 = attention1 + attention2
#     attention2 = LayerNormalization(epsilon=1e-6)(attention2)

#     ff_output = Dense(ff_dim, activation="relu")(attention2)
#     ff_output = Dense(input_dim)(ff_output)
#     ff_output = Dropout(dropout_rate)(ff_output)

#     return LayerNormalization(epsilon=1e-6)(attention2 + ff_output)

# # Build Transformer Model
# def build_transformer_model(input_shape, target_shape, num_heads=4, ff_dim=64):
#     encoder_inputs = Input(shape=input_shape, name="encoder_inputs")
#     encoder_outputs = transformer_encoder(encoder_inputs, num_heads, ff_dim)
#     encoder_outputs = transformer_encoder(encoder_outputs, num_heads, ff_dim)

#     decoder_inputs = Input(shape=target_shape, name="decoder_inputs")
#     decoder_outputs = transformer_decoder(decoder_inputs, encoder_outputs, num_heads, ff_dim)
#     decoder_outputs = transformer_decoder(decoder_outputs, encoder_outputs, num_heads, ff_dim)

#     # Preserve Temporal Structure with TimeDistributed
#     x = TimeDistributed(Dense(32, activation="relu"))(decoder_outputs)
#     outputs = TimeDistributed(Dense(target_shape[-1]))(x)  # Output per time step

#     model = Model([encoder_inputs, decoder_inputs], outputs)
#     return model

# # Define target shape correctly
# target_shape = (seq_length, X_train.shape[-1])  # Adjusted to match correct sequence length

# # Build model
# model = build_transformer_model((seq_length, X_train.shape[2]), target_shape, num_heads=4, ff_dim=64)

# # Compile Model
# model.compile(optimizer=Adam(learning_rate=0.001), loss="mse", metrics=['accuracy'])

# # Train Model
# history = model.fit(
#     [X_train, decoder_inputs_train], decoder_targets_train,
#     epochs=50, batch_size=16,
#     validation_data=([X_test, decoder_inputs_test], decoder_targets_test)
# )

# # Plot Training History
# plt.plot(history.history['loss'], label='Train Loss')
# plt.plot(history.history['val_loss'], label='Val Loss')
# plt.legend()
# plt.title("Training Loss")
# plt.xlabel("Epochs")
# plt.ylabel("Loss")
# plt.show()

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Dense, MultiHeadAttention, LayerNormalization, Dropout,
    TimeDistributed, Lambda, Embedding
)
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import MinMaxScaler
import pandas as pd

# Data Preprocessing
train_size = int(len(df) * 0.8)
train_data, test_data = df.iloc[:train_size], df.iloc[train_size:]

# Scale data separately to prevent leakage
scaler = MinMaxScaler()
scaled_train = scaler.fit_transform(train_data)
scaled_test = scaler.transform(test_data)

# Pad features to make even
if scaled_train.shape[1] % 2 != 0:
    scaled_train = np.hstack([scaled_train, np.zeros((scaled_train.shape[0], 1))])
    scaled_test = np.hstack([scaled_test, np.zeros((scaled_test.shape[0], 1))])

# Positional Encoding Layer
class PositionalEncoding(tf.keras.layers.Layer):
    def __init__(self):
        super().__init__()

    def build(self, input_shape):
        _, seq_len, d_model = input_shape

        if d_model % 2 != 0:  # Ensure even d_model
            raise ValueError(f"d_model must be even, but got {d_model}")

        pos = np.arange(seq_len)[:, np.newaxis]
        div_term = np.exp(np.arange(0, d_model, 2) * (-np.log(10000.0) / d_model))

        pe = np.zeros((seq_len, d_model))
        pe[:, 0::2] = np.sin(pos * div_term)
        pe[:, 1::2] = np.cos(pos * div_term)
        self.pe = tf.constant(pe[np.newaxis, ...], dtype=tf.float32)

    def call(self, inputs):
        return inputs + self.pe[:, :tf.shape(inputs)[1], :]

# Learned Start Token
start_token_layer = Embedding(input_dim=1, output_dim=df.shape[1])

def create_sequences(data, seq_length):
    X, decoder_inputs, decoder_targets = [], [], []

    for i in range(len(data) - seq_length - 1):
        X.append(data[i:i+seq_length])

        # Ensure start token matches feature dimension
        start_token = start_token_layer(tf.zeros((1, 1), dtype=tf.int32)).numpy()[0]

        # Adjust dimensions if needed
        if start_token.shape[0] != data.shape[1]:
            start_token = np.zeros((data.shape[1],))  # Ensure same shape

        decoder_in = np.vstack([start_token, data[i+1:i+seq_length]])

        # Decoder target
        decoder_target = data[i+1:i+seq_length+1]

        decoder_inputs.append(decoder_in)
        decoder_targets.append(decoder_target)

    return np.array(X), np.array(decoder_inputs), np.array(decoder_targets)

seq_length = 10  # Fixed step size
X_train, decoder_inputs_train, decoder_targets_train = create_sequences(scaled_train, seq_length)
X_test, decoder_inputs_test, decoder_targets_test = create_sequences(scaled_test, seq_length)

# Ensure feature_dim is even
# Remove these lines:
feature_dim = X_train.shape[2]
if feature_dim % 2 != 0:
    feature_dim += 1

# Transformer Encoder Block
def transformer_encoder(inputs, num_heads=4, ff_dim=64, dropout_rate=0.1):
    input_dim = tf.keras.backend.int_shape(inputs)[-1]
    key_dim = max(1, input_dim // num_heads)

    attention_norm = LayerNormalization(epsilon=1e-6)(inputs)
    attention = MultiHeadAttention(num_heads=num_heads, key_dim=key_dim)(attention_norm, attention_norm)
    attention = Dropout(dropout_rate)(attention)
    attention = inputs + attention
    attention = LayerNormalization(epsilon=1e-6)(attention)

    ff_output = Dense(ff_dim, activation="relu")(attention)
    ff_output = Dense(input_dim)(ff_output)
    ff_output = Dropout(dropout_rate)(ff_output)

    return LayerNormalization(epsilon=1e-6)(attention + ff_output)

# Transformer Decoder Block with Corrected Causal Mask
def create_causal_mask(seq_len):
    mask = tf.linalg.band_part(tf.ones((seq_len, seq_len)), -1, 0)
    mask = tf.where(mask == 0, -np.inf, 0)
    return mask

def transformer_decoder(inputs, encoder_outputs, num_heads=4, ff_dim=64, dropout_rate=0.1):
    input_dim = tf.keras.backend.int_shape(inputs)[-1]
    key_dim = max(1, input_dim // num_heads)

    causal_mask = Lambda(lambda x: create_causal_mask(tf.shape(x)[1]))(inputs)

    attention_norm = LayerNormalization(epsilon=1e-6)(inputs)
    attention1 = MultiHeadAttention(num_heads=num_heads, key_dim=key_dim)(
        attention_norm, attention_norm, attention_mask=causal_mask
    )
    attention1 = Dropout(dropout_rate)(attention1)
    attention1 = inputs + attention1
    attention1 = LayerNormalization(epsilon=1e-6)(attention1)

    attention2 = MultiHeadAttention(num_heads=num_heads, key_dim=key_dim)(
        query=attention1, key=encoder_outputs, value=encoder_outputs
    )
    attention2 = Dropout(dropout_rate)(attention2)
    attention2 = attention1 + attention2
    attention2 = LayerNormalization(epsilon=1e-6)(attention2)

    ff_output = Dense(ff_dim, activation="relu")(attention2)
    ff_output = Dense(input_dim)(ff_output)
    ff_output = Dropout(dropout_rate)(ff_output)

    return LayerNormalization(epsilon=1e-6)(attention2 + ff_output)

# Build Transformer Model
def build_transformer_model(input_shape, target_shape, num_heads=4, ff_dim=64):
    encoder_inputs = Input(shape=input_shape, name="encoder_inputs")
    x = PositionalEncoding()(encoder_inputs)  # Add positional encoding
    encoder_outputs = transformer_encoder(x, num_heads, ff_dim)
    encoder_outputs = transformer_encoder(encoder_outputs, num_heads, ff_dim)

    decoder_inputs = Input(shape=target_shape, name="decoder_inputs")
    x = PositionalEncoding()(decoder_inputs)  # Add positional encoding
    decoder_outputs = transformer_decoder(x, encoder_outputs, num_heads, ff_dim)
    decoder_outputs = transformer_decoder(decoder_outputs, encoder_outputs, num_heads, ff_dim)

    x = TimeDistributed(Dense(32, activation="relu"))(decoder_outputs)
    outputs = TimeDistributed(Dense(target_shape[-1]))(x)

    return Model([encoder_inputs, decoder_inputs], outputs)

# Define target shape correctly
target_shape = (seq_length, X_train.shape[-1])


# Train Model
# Build model with corrected dimensions
model = build_transformer_model(
    (seq_length, scaled_train.shape[1]),  # Now has even features
    (seq_length, scaled_train.shape[1]),   # Same for decoder
    num_heads=4,
    ff_dim=64
)

# Compile Model
model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss="mse",
    metrics=[tf.keras.metrics.MeanAbsoluteError(),'accuracy']
)

model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ encoder_inputs            │ (None, 10, 8)          │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ positional_encoding_2     │ (None, 10, 8)          │              0 │ encoder_inputs[0][0]   │
# │ (PositionalEncoding)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_14    │ (None, 10, 8)          │             16 │ positional_encoding_2… │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_6    │ (None, 10, 8)          │            288 │ layer_normalization_1… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_17 (Dropout)      │ (None, 10, 8)          │              0 │ multi_head_attention_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_10 (Add)              │ (None, 10, 8)          │              0 │ positional_encoding_2… │
# │                           │                        │                │ dropout_17[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_15    │ (None, 10, 8)          │             16 │ add_10[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_10 (Dense)          │ (None, 10, 64)         │            576 │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_11 (Dense)          │ (None, 10, 8)          │            520 │ dense_10[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_18 (Dropout)      │ (None, 10, 8)          │              0 │ dense_11[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_11 (Add)              │ (None, 10, 8)          │              0 │ layer_normalization_1… │
# │                           │                        │                │ dropout_18[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_16    │ (None, 10, 8)          │             16 │ add_11[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_17    │ (None, 10, 8)          │             16 │ layer_normalization_1… │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_7    │ (None, 10, 8)          │            288 │ layer_normalization_1… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_20 (Dropout)      │ (None, 10, 8)          │              0 │ multi_head_attention_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ decoder_inputs            │ (None, 10, 8)          │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_12 (Add)              │ (None, 10, 8)          │              0 │ layer_normalization_1… │
# │                           │                        │                │ dropout_20[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ positional_encoding_3     │ (None, 10, 8)          │              0 │ decoder_inputs[0][0]   │
# │ (PositionalEncoding)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_18    │ (None, 10, 8)          │             16 │ add_12[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_20    │ (None, 10, 8)          │             16 │ positional_encoding_3… │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_2 (Lambda)         │ (10, 10)               │              0 │ positional_encoding_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_12 (Dense)          │ (None, 10, 64)         │            576 │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_8    │ (None, 10, 8)          │            288 │ layer_normalization_2… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_2… │
# │                           │                        │                │ lambda_2[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_13 (Dense)          │ (None, 10, 8)          │            520 │ dense_12[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_23 (Dropout)      │ (None, 10, 8)          │              0 │ multi_head_attention_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_21 (Dropout)      │ (None, 10, 8)          │              0 │ dense_13[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_14 (Add)              │ (None, 10, 8)          │              0 │ positional_encoding_3… │
# │                           │                        │                │ dropout_23[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_13 (Add)              │ (None, 10, 8)          │              0 │ layer_normalization_1… │
# │                           │                        │                │ dropout_21[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_21    │ (None, 10, 8)          │             16 │ add_14[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_19    │ (None, 10, 8)          │             16 │ add_13[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_9    │ (None, 10, 8)          │            288 │ layer_normalization_1… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_2… │
# │                           │                        │                │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_25 (Dropout)      │ (None, 10, 8)          │              0 │ multi_head_attention_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_15 (Add)              │ (None, 10, 8)          │              0 │ layer_normalization_2… │
# │                           │                        │                │ dropout_25[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_22    │ (None, 10, 8)          │             16 │ add_15[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_14 (Dense)          │ (None, 10, 64)         │            576 │ layer_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_15 (Dense)          │ (None, 10, 8)          │            520 │ dense_14[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_26 (Dropout)      │ (None, 10, 8)          │              0 │ dense_15[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_16 (Add)              │ (None, 10, 8)          │              0 │ layer_normalization_2… │
# │                           │                        │                │ dropout_26[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_23    │ (None, 10, 8)          │             16 │ add_16[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_24    │ (None, 10, 8)          │             16 │ layer_normalization_2… │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_3 (Lambda)         │ (10, 10)               │              0 │ layer_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_10   │ (None, 10, 8)          │            288 │ layer_normalization_2… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_2… │
# │                           │                        │                │ lambda_3[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_28 (Dropout)      │ (None, 10, 8)          │              0 │ multi_head_attention_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_17 (Add)              │ (None, 10, 8)          │              0 │ layer_normalization_2… │
# │                           │                        │                │ dropout_28[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_25    │ (None, 10, 8)          │             16 │ add_17[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_11   │ (None, 10, 8)          │            288 │ layer_normalization_1… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_2… │
# │                           │                        │                │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_30 (Dropout)      │ (None, 10, 8)          │              0 │ multi_head_attention_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_18 (Add)              │ (None, 10, 8)          │              0 │ layer_normalization_2… │
# │                           │                        │                │ dropout_30[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_26    │ (None, 10, 8)          │             16 │ add_18[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_16 (Dense)          │ (None, 10, 64)         │            576 │ layer_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_17 (Dense)          │ (None, 10, 8)          │            520 │ dense_16[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_31 (Dropout)      │ (None, 10, 8)          │              0 │ dense_17[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_19 (Add)              │ (None, 10, 8)          │              0 │ layer_normalization_2… │
# │                           │                        │                │ dropout_31[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_27    │ (None, 10, 8)          │             16 │ add_19[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ time_distributed_2        │ (None, 10, 32)         │            288 │ layer_normalization_2… │
# │ (TimeDistributed)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ time_distributed_3        │ (None, 10, 8)          │            264 │ time_distributed_2[0]… │
# │ (TimeDistributed)         │                        │                │                        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 6,888 (26.91 KB)
#  Trainable params: 6,888 (26.91 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train Model
history = model.fit(
    [X_train, decoder_inputs_train], decoder_targets_train,
    epochs=50, batch_size=32,
    validation_data=([X_test, decoder_inputs_test], decoder_targets_test)
)

# Plot Training History
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.legend()
plt.title("Training Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.show()
# Out:
# Epoch 1/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 29s 1s/step - accuracy: 0.0408 - loss: 0.3862 - mean_absolute_error: 0.4601 - val_accuracy: 0.0000e+00 - val_loss: 1262971.3750 - val_mean_absolute_error: 86.3435
# Epoch 2/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.0868 - loss: 0.2635 - mean_absolute_error: 0.3980 - val_accuracy: 0.1077 - val_loss: 1262983.6250 - val_mean_absolute_error: 86.2742
# Epoch 3/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.1462 - loss: 0.1823 - mean_absolute_error: 0.3475 - val_accuracy: 0.1077 - val_loss: 1262978.3750 - val_mean_absolute_error: 86.2341
# Epoch 4/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.1577 - loss: 0.1411 - mean_absolute_error: 0.3071 - val_accuracy: 0.1538 - val_loss: 1262964.0000 - val_mean_absolute_error: 86.1995
# Epoch 5/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - accuracy: 0.1959 - loss: 0.1116 - mean_absolute_error: 0.2705 - val_accuracy: 0.2846 - val_loss: 1262949.3750 - val_mean_absolute_error: 86.1696
# Epoch 6/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.3805 - loss: 0.0896 - mean_absolute_error: 0.2418 - val_accuracy: 0.5231 - val_loss: 1262939.5000 - val_mean_absolute_error: 86.1496
# Epoch 7/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5509 - loss: 0.0734 - mean_absolute_error: 0.2197 - val_accuracy: 0.5923 - val_loss: 1262933.0000 - val_mean_absolute_error: 86.1395
# Epoch 8/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6335 - loss: 0.0639 - mean_absolute_error: 0.2041 - val_accuracy: 0.6154 - val_loss: 1262930.7500 - val_mean_absolute_error: 86.1337
# Epoch 9/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6026 - loss: 0.0631 - mean_absolute_error: 0.1983 - val_accuracy: 0.6231 - val_loss: 1262935.5000 - val_mean_absolute_error: 86.1262
# Epoch 10/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6242 - loss: 0.0598 - mean_absolute_error: 0.1906 - val_accuracy: 0.6308 - val_loss: 1262943.5000 - val_mean_absolute_error: 86.1195
# Epoch 11/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.6556 - loss: 0.0561 - mean_absolute_error: 0.1832 - val_accuracy: 0.6308 - val_loss: 1262949.6250 - val_mean_absolute_error: 86.1135
# Epoch 12/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6366 - loss: 0.0567 - mean_absolute_error: 0.1814 - val_accuracy: 0.6308 - val_loss: 1262954.7500 - val_mean_absolute_error: 86.1100
# Epoch 13/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6610 - loss: 0.0550 - mean_absolute_error: 0.1787 - val_accuracy: 0.6308 - val_loss: 1262957.6250 - val_mean_absolute_error: 86.1086
# Epoch 14/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6612 - loss: 0.0537 - mean_absolute_error: 0.1752 - val_accuracy: 0.6308 - val_loss: 1262958.5000 - val_mean_absolute_error: 86.1073
# Epoch 15/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.6621 - loss: 0.0540 - mean_absolute_error: 0.1747 - val_accuracy: 0.6308 - val_loss: 1262958.0000 - val_mean_absolute_error: 86.1059
# Epoch 16/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6561 - loss: 0.0530 - mean_absolute_error: 0.1714 - val_accuracy: 0.6308 - val_loss: 1262956.2500 - val_mean_absolute_error: 86.1046
# Epoch 17/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6564 - loss: 0.0532 - mean_absolute_error: 0.1697 - val_accuracy: 0.6308 - val_loss: 1262954.3750 - val_mean_absolute_error: 86.1035
# Epoch 18/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6460 - loss: 0.0537 - mean_absolute_error: 0.1716 - val_accuracy: 0.6308 - val_loss: 1262952.3750 - val_mean_absolute_error: 86.1022
# Epoch 19/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6745 - loss: 0.0522 - mean_absolute_error: 0.1698 - val_accuracy: 0.6308 - val_loss: 1262950.6250 - val_mean_absolute_error: 86.1008
# Epoch 20/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6670 - loss: 0.0503 - mean_absolute_error: 0.1659 - val_accuracy: 0.6308 - val_loss: 1262949.2500 - val_mean_absolute_error: 86.0994
# Epoch 21/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6605 - loss: 0.0512 - mean_absolute_error: 0.1680 - val_accuracy: 0.6308 - val_loss: 1262948.2500 - val_mean_absolute_error: 86.0986
# Epoch 22/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6774 - loss: 0.0513 - mean_absolute_error: 0.1683 - val_accuracy: 0.6308 - val_loss: 1262947.7500 - val_mean_absolute_error: 86.0977
# Epoch 23/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6628 - loss: 0.0514 - mean_absolute_error: 0.1697 - val_accuracy: 0.6308 - val_loss: 1262947.5000 - val_mean_absolute_error: 86.0975
# Epoch 24/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6716 - loss: 0.0502 - mean_absolute_error: 0.1669 - val_accuracy: 0.6308 - val_loss: 1262947.5000 - val_mean_absolute_error: 86.0971
# Epoch 25/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6684 - loss: 0.0509 - mean_absolute_error: 0.1677 - val_accuracy: 0.6308 - val_loss: 1262948.0000 - val_mean_absolute_error: 86.0966
# Epoch 26/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6597 - loss: 0.0508 - mean_absolute_error: 0.1668 - val_accuracy: 0.6308 - val_loss: 1262948.6250 - val_mean_absolute_error: 86.0965
# Epoch 27/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6651 - loss: 0.0514 - mean_absolute_error: 0.1675 - val_accuracy: 0.6308 - val_loss: 1262949.2500 - val_mean_absolute_error: 86.0962
# Epoch 28/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6657 - loss: 0.0493 - mean_absolute_error: 0.1646 - val_accuracy: 0.6308 - val_loss: 1262949.8750 - val_mean_absolute_error: 86.0959
# Epoch 29/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6541 - loss: 0.0502 - mean_absolute_error: 0.1659 - val_accuracy: 0.6308 - val_loss: 1262949.7500 - val_mean_absolute_error: 86.0959
# Epoch 30/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.6565 - loss: 0.0506 - mean_absolute_error: 0.1658 - val_accuracy: 0.6308 - val_loss: 1262949.6250 - val_mean_absolute_error: 86.0955
# Epoch 31/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6634 - loss: 0.0502 - mean_absolute_error: 0.1652 - val_accuracy: 0.6308 - val_loss: 1262949.6250 - val_mean_absolute_error: 86.0947
# Epoch 32/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6657 - loss: 0.0489 - mean_absolute_error: 0.1628 - val_accuracy: 0.6308 - val_loss: 1262950.0000 - val_mean_absolute_error: 86.0940
# Epoch 33/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6755 - loss: 0.0490 - mean_absolute_error: 0.1628 - val_accuracy: 0.6308 - val_loss: 1262950.3750 - val_mean_absolute_error: 86.0937
# Epoch 34/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6512 - loss: 0.0491 - mean_absolute_error: 0.1625 - val_accuracy: 0.6308 - val_loss: 1262950.8750 - val_mean_absolute_error: 86.0944
# Epoch 35/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6597 - loss: 0.0485 - mean_absolute_error: 0.1618 - val_accuracy: 0.6308 - val_loss: 1262951.1250 - val_mean_absolute_error: 86.0949
# Epoch 36/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6520 - loss: 0.0492 - mean_absolute_error: 0.1632 - val_accuracy: 0.6308 - val_loss: 1262950.8750 - val_mean_absolute_error: 86.0947
# Epoch 37/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6498 - loss: 0.0494 - mean_absolute_error: 0.1631 - val_accuracy: 0.6308 - val_loss: 1262950.7500 - val_mean_absolute_error: 86.0934
# Epoch 38/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6546 - loss: 0.0479 - mean_absolute_error: 0.1611 - val_accuracy: 0.6308 - val_loss: 1262950.8750 - val_mean_absolute_error: 86.0917
# Epoch 39/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6725 - loss: 0.0478 - mean_absolute_error: 0.1595 - val_accuracy: 0.6308 - val_loss: 1262950.8750 - val_mean_absolute_error: 86.0904
# Epoch 40/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6684 - loss: 0.0482 - mean_absolute_error: 0.1598 - val_accuracy: 0.6308 - val_loss: 1262951.1250 - val_mean_absolute_error: 86.0900
# Epoch 41/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6751 - loss: 0.0471 - mean_absolute_error: 0.1579 - val_accuracy: 0.6308 - val_loss: 1262950.8750 - val_mean_absolute_error: 86.0903
# Epoch 42/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6528 - loss: 0.0479 - mean_absolute_error: 0.1601 - val_accuracy: 0.6308 - val_loss: 1262950.8750 - val_mean_absolute_error: 86.0907
# Epoch 43/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6515 - loss: 0.0485 - mean_absolute_error: 0.1604 - val_accuracy: 0.6308 - val_loss: 1262950.8750 - val_mean_absolute_error: 86.0895
# Epoch 44/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6618 - loss: 0.0470 - mean_absolute_error: 0.1576 - val_accuracy: 0.6308 - val_loss: 1262951.0000 - val_mean_absolute_error: 86.0876
# Epoch 45/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6632 - loss: 0.0478 - mean_absolute_error: 0.1585 - val_accuracy: 0.6308 - val_loss: 1262951.3750 - val_mean_absolute_error: 86.0876
# Epoch 46/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6587 - loss: 0.0471 - mean_absolute_error: 0.1577 - val_accuracy: 0.6308 - val_loss: 1262951.3750 - val_mean_absolute_error: 86.0890
# Epoch 47/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6725 - loss: 0.0459 - mean_absolute_error: 0.1557 - val_accuracy: 0.6308 - val_loss: 1262951.5000 - val_mean_absolute_error: 86.0890
# Epoch 48/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6262 - loss: 0.0485 - mean_absolute_error: 0.1601 - val_accuracy: 0.6308 - val_loss: 1262951.6250 - val_mean_absolute_error: 86.0883
# Epoch 49/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.6470 - loss: 0.0466 - mean_absolute_error: 0.1563 - val_accuracy: 0.6308 - val_loss: 1262951.8750 - val_mean_absolute_error: 86.0863
# Epoch 50/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.6645 - loss: 0.0468 - mean_absolute_error: 0.1564 - val_accuracy: 0.6308 - val_loss: 1262952.1250 - val_mean_absolute_error: 86.0851

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Number of future steps
future_steps = 10
future_predictions = []

# Initialize input sequence from the last test sample
input_seq = X_test[-1].reshape(1, seq_length, X_train.shape[2])  # Match input shape

for _ in range(future_steps):
    pred = model.predict([input_seq, input_seq], verbose=0)  # Both encoder & decoder inputs

    future_predictions.append(pred[0, -1, :])  # Take last predicted timestep

    # Shift input sequence and insert new prediction
    input_seq = np.roll(input_seq, -1, axis=1)
    input_seq[0, -1, :] = future_predictions[-1]  # Insert prediction into last time step

# Convert to NumPy array
future_predictions = np.array(future_predictions)

# 🔥 Remove the last feature (8th column) before inverse scaling
future_predictions = future_predictions[:, :-1]  # Exclude last column

# Convert predictions back to original scale
future_predictions = scaler.inverse_transform(future_predictions)

# ✅ Ensure column count matches predictions
expected_columns = df.columns[:future_predictions.shape[1]]  # Select the correct number of columns

# Create timestamps for predicted values
forecast_df = pd.DataFrame(future_predictions, columns=expected_columns)

# 🔹 Plot Actual vs. Predicted Values
plt.figure(figsize=(10, 5))
plt.plot(df["x"], label="Actual X", color="blue")
plt.plot(forecast_df["x"], label="Predicted X", color="red", linestyle="dashed")
plt.legend()
plt.xlabel("Time")
plt.ylabel("Value")
plt.title("Future Predictions")
plt.grid()
plt.show()

print(forecast_df)
# Out:
#             x            y            z  duration_seconds   distance_km  \
# 0 -540.596436 -5143.729004  3450.384766         66.183647 -2.973465e-05
# 1 -541.966370 -4979.271484  3420.500000         64.925789  4.575440e-06
# 2 -547.904846 -4939.226562  3437.733398         64.788208  5.349293e-07
# 3 -563.192810 -4874.747559  3470.177002         64.840073  6.733484e-06
# 4 -563.695557 -4854.991211  3483.892822         65.082916  2.000008e-05
# 5 -541.421509 -4979.264160  3432.713135         65.327446  2.023999e-05
# 6 -514.112244 -5000.736816  3440.633545         65.822655  3.118869e-05
# 7 -507.784698 -4944.006836  3479.806152         66.161026  4.602860e-05
# 8 -488.997101 -5005.217285  3462.333008         66.330147  4.338635e-05
# 9 -488.120422 -4997.702637  3465.477783         66.289093  4.114095e-05
#
#     sog_mps  cog_radians
# 0  3.097261     2.624594
# 1  2.824033     2.810371
# 2  2.806378     2.815725
# 3  2.744125     2.853911
# 4  2.700060     2.877846
# 5  2.786205     2.821255
# 6  2.737340     2.868896
# 7  2.639630     2.925601
# 8  2.693411     2.876434
# 9  2.688651     2.883389

# %%
# import tensorflow as tf
# from tensorflow.keras.optimizers import Adam

# # Check for GPU availability and set device accordingly
# if tf.config.list_physical_devices('GPU'):
#     print("GPU Available, using GPU...")
#     device = '/GPU:0'
#     # Enable GPU memory growth
#     gpus = tf.config.experimental.list_physical_devices('GPU')
#     if gpus:
#         try:
#             for gpu in gpus:
#                 tf.config.experimental.set_memory_growth(gpu, True)
#         except RuntimeError as e:
#             print("Error enabling memory growth:", e)
# else:
#     print("GPU not available, using CPU...")
#     device = '/CPU:0'

# # Build and compile model inside a GPU strategy scope (if GPU is available)
# strategy = tf.distribute.MirroredStrategy() if tf.config.list_physical_devices('GPU') else tf.distribute.get_strategy()
# with strategy.scope():
#     # Build the transformer model (adjust dimensions based on your input data)
#     model = build_transformer_model(
#         input_shape=(seq_length, scaled_train.shape[1]),  # Adjust based on your input data shape
#         target_shape=(seq_length, scaled_train.shape[1]),  # Adjust based on your target data shape
#         num_heads=4,
#         ff_dim=64
#     )

#     # Use mixed precision if a GPU is available
#     if tf.config.list_physical_devices('GPU'):
#         tf.keras.mixed_precision.set_global_policy('mixed_float16')

#     # Compile the model
#     model.compile(
#         optimizer=Adam(learning_rate=0.001),
#         loss="mse",
#         metrics=[tf.keras.metrics.MeanAbsoluteError()]
#     )

# # Check the shapes of the input and target data
# print("X_train shape:", X_train.shape)
# print("decoder_inputs_train shape:", decoder_inputs_train.shape)
# print("decoder_targets_train shape:", decoder_targets_train.shape)

# # Ensure that the input shapes are compatible
# # Create the train and test datasets using `from_tensor_slices`
# train_dataset = tf.data.Dataset.from_tensor_slices(
#     (X_train, decoder_inputs_train, decoder_targets_train)  # Align input and target shapes
# ).shuffle(1024).batch(128).prefetch(tf.data.AUTOTUNE)

# test_dataset = tf.data.Dataset.from_tensor_slices(
#     (X_test, decoder_inputs_test, decoder_targets_test)  # Align input and target shapes
# ).batch(128).prefetch(tf.data.AUTOTUNE)

# # Train the model with the dataset
# history = model.fit(
#     train_dataset,
#     epochs=100,  # Increased epochs for better convergence
#     validation_data=test_dataset,
#     callbacks=[
#         tf.keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True),
#         tf.keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=5)
#     ]
# )
